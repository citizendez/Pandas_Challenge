# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load CSV
coders = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
coders_df = pd.read_csv(coders, encoding = 'iso-8859-1', low_memory = False)
coders_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
new_df = coders_df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
new_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
yesno_df = new_df.replace({0: "No", 1: "Yes"})

yesno_df.tail()
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 15615  39.0               No            NaN                  NaN
# 15616  27.0               No            NaN                  NaN
# 15617  37.0               No            NaN                  NaN
# 15618  26.0               No            NaN                  NaN
# 15619  22.0               No            NaN                  NaN
#
#       BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 15615               NaN                 NaN               NaN            NaN
# 15616               NaN                 NaN               NaN            NaN
# 15617               NaN                 NaN               NaN            NaN
# 15618               NaN                 NaN               NaN            NaN
# 15619               NaN                 NaN               NaN            NaN
#
#             CityPopulation CodeEventBootcamp               CountryLive  \
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended = yesno_df.loc[yesno_df["AttendedBootcamp"]=="Yes"]
attended
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93     32.0              Yes            Yes                   No
# 97     26.0              Yes            Yes                  Yes
# 130    41.0              Yes            Yes                  Yes
# 159    26.0              Yes            Yes                   No
# 188    24.0              Yes             No                  NaN
# ...     ...              ...            ...                  ...
# 15539  39.0              Yes            Yes                  Yes
# 15540  24.0              Yes            Yes                  Yes
# 15541  23.0              Yes            Yes                  Yes
# 15593  29.0              Yes             No                  NaN
# 15600  28.0              Yes            Yes                  Yes
#
#       BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                   No                 NaN                No            NaN
# ...

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
bootcamps = pd.DataFrame(coders_df["BootcampName"].value_counts())
bootcamps.reset_index(inplace=True)
bootcamps.columns = ["BootcampName", "Number of Attendees"]
bootcamps_df = bootcamps.loc[(bootcamps["Number of Attendees"] >= 10)]
bootcamps_df.head()
#jugement call on what significant means
#x=bootcamps["Number of Attendees"] 
#plt.hist(x, density=True, bins=60) 
#plt.show()
# Out:
#             BootcampName  Number of Attendees
# 0       General Assembly                   90
# 1        Flatiron School                   54
# 2           Dev Bootcamp                   48
# 3          The Iron Yard                   40
# 4  Prime Digital Academy                   30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommenders_df = coders_df.replace({"No":0, "Yes":1})

#recommenders_yes = recommenders_df.loc[recommenders_df["BootcampRecommend"]=="Yes"]

recommenders_df = pd.DataFrame(coders_df.groupby("BootcampName")["BootcampRecommend"].sum())
recommenders_df.reset_index(inplace=True)
recommenders_df.columns = ["BootcampName", "Number of Recommenders"]
recommenders_df.head()
# Out:
#             BootcampName  Number of Recommenders
# 0             10x.org.il                     3.0
# 1         4Geeks Academy                     4.0
# 2               AcadGild                     2.0
# 3    Academia de CÃ³digo                     4.0
# 4  Academic Work Academy                     0.0

# %%
# Merge the two created data frames on the name of tbe bootcamp
df_merged = pd.merge(recommenders_df, bootcamps_df, on='BootcampName', how='left')
df_merged.head(500)
# Out:
#               BootcampName  Number of Recommenders  Number of Attendees
# 0               10x.org.il                     3.0                  NaN
# 1           4Geeks Academy                     4.0                  NaN
# 2                 AcadGild                     2.0                  NaN
# 3      Academia de CÃ³digo                     4.0                  NaN
# 4    Academic Work Academy                     0.0                  NaN
# ..                     ...                     ...                  ...
# 123                Wyncode                     3.0                  NaN
# 124    Zip Code Wilmington                     1.0                  NaN
# 125                  codeU                     1.0                  NaN
# 126            devCodeCamp                     4.0                  NaN
# 127             tradecraft                     1.0                  NaN
#
# [128 rows x 3 columns]

# %%
# Calculate percentage of eac bootcamp's students who are recommenders
df_merged["Percentage of Recommended"] = round(df_merged["Number of Recommenders"]/df_merged["Number of Attendees"] *100,3)

# %%
df_merged["Percentage of Recommended"]=df_merged["Percentage of Recommended"].map('{:.2f}%'.format)
df_merged
# Out:
#               BootcampName  Number of Recommenders  Number of Attendees  \
# 0               10x.org.il                     3.0                  NaN
# 1           4Geeks Academy                     4.0                  NaN
# 2                 AcadGild                     2.0                  NaN
# 3      Academia de CÃ³digo                     4.0                  NaN
# 4    Academic Work Academy                     0.0                  NaN
# ..                     ...                     ...                  ...
# 123                Wyncode                     3.0                  NaN
# 124    Zip Code Wilmington                     1.0                  NaN
# 125                  codeU                     1.0                  NaN
# 126            devCodeCamp                     4.0                  NaN
# 127             tradecraft                     1.0                  NaN
#
#     Percentage of Recommended
# 0                        nan%
# 1                        nan%
# ...

# %%
# Export to excel and remove index
df_merged.to_csv("output/des_output_part_two.csv", index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-57-3205f5526353> in <module>
#       1 # Export to excel and remove index
# ----> 2 df_merged.to_csv("output/des_output_part_two.csv", index=False, header=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     182             close = False
#     183         else:
# --> 184             f, handles = get_handle(
#     185                 self.path_or_buf,
# ...
